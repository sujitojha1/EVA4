# %% [markdown]
# <a href="https://colab.research.google.com/github/sujitojha1/EVA4/blob/rev4/S11/EVA4_S11_Solution_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Statement EVA 4, Session11 : CIFAR 10
#
# **Target**:
#
#
# *  Write a code that draws this curve (without the arrows). In submission, you'll upload your drawn curve and code for that
#     * 11s11.png
# *  Write a code which
#   1. uses this new ResNet Architecture for Cifar10:
#     * PrepLayer - Conv 3x3 s1, p1) >> BN >> RELU [64k]
#     * Layer1 -
#         * X = Conv 3x3 (s1, p1) >> MaxPool2D >> BN >> RELU [128k]
#         * R1 = ResBlock( (Conv-BN-ReLU-Conv-BN-ReLU))(X) [128k]
#         * Add(X, R1)
#     * Layer 2 -
#         * Conv 3x3 [256k]
#         * MaxPooling2D
#         * BN
#         * ReLU
#     * Layer 3 -
#         * X = Conv 3x3 (s1, p1) >> MaxPool2D >> BN >> RELU [512k]
#         * R2 = ResBlock( (Conv-BN-ReLU-Conv-BN-ReLU))(X) [512k]
#         * Add(X, R2)
#     * MaxPooling with Kernel Size 4
#     * FC Layer
#     * SoftMax
#   2. Uses One Cycle Policy such that:
#     * Total Epochs = 24
#     * Max at Epoch = 5
#     * LRMIN = FIND
#     * LRMAX = FIND
#     * NO Annihilation
#   3. Uses this transform -RandomCrop 32, 32 (after padding of 4) >> FlipLR >> Followed by CutOut(8, 8)
#   4. Batch size = 512
#   5. Target Accuracy: 90%.
#   6. The lesser the modular your code is (i.e. more the code you have written in your Colab file), less marks you'd get.
# * Questions asked are:
#   1. Upload the code you used to draw your ZIGZAG or CYCLIC TRIANGLE plot.
#   2. Upload your triangle Plot which was drawn with your code.
#   3. Upload the link to your GitHub copy of Colab Code.
#   4. Upload the github link for the model as described in A11.
#   5. What is your test accuracy?
#
# **Results**
#
# *  Total Parameters = 6,573,120
# *  After 24 Epochs, Final Train Accuracy = 95.75%
# *  After 24 Epochs, Final Test Accuracy = 90.27%
#
# **Analysis**
#
# *  Target accuracy > 90% using Reset18 new architecture. Model performance is slightly overfitting.

# %% [markdown]
# ## 1. Loading Module and Models

# %%
# Load modules/models from EVA course
# !rm -rf EVA4
# !git clone -b rev4 https://github.com/sujitojha1/EVA4 -q --quiet
print("Loaded EVA4 Modules and Models")

# Installing latest Albumentation library
# !pip install -U git+https://github.com/albu/albumentations -q --quiet
#pip install apex -q

# For inline matplotlib plotting
# %matplotlib inline
# Out:
# Loaded EVA4 Modules and Models
#   Building wheel for albumentations (setup.py) ... done

# %% [markdown]
# ## 2. Loading train and test data with transforms and loader functions

# %%
from EVA4.Modules import *

# Loading test and train data & dataloader
cifar10 = dataset_cifar10(batch_size=512)

# Train dataloader
trainloader = cifar10.loader(train_flag=True)

# Test dataloader
testloader = cifar10.loader(train_flag=False)

classes = cifar10.classes
# Out:
# CUDA availability ? True
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./Data/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./Data/cifar-10-python.tar.gz to ./Data
# Files already downloaded and verified

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %% [markdown]
# ### 3.1 Summary Statistics

# %%
cifar10.data_summary_stats()
#print(vars(train))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (60000, 32, 32, 3)
# [0.49186878 0.48265391 0.44717728]
# [0.24697121 0.24338894 0.26159259]

# %% [markdown]
# ### 3.2 Plotting sample images

# %%
cifar10.sample_pictures(train_flag=True)
# Out:
# Files already downloaded and verified

# %% [markdown]
# # The Model

# %%
from EVA4.Models import *

# Loading ResNet18 Model
net = ResNet_Cifar10()

# Using cuda if available
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)

# Sending network to device
net = net.to(device)
# Out:
# cuda

# %% [markdown]
# # Model Summary

# %%
# !pip install torchsummary
from torchsummary import summary

# Model Summary
summary(net, input_size=(3, 32, 32))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4          [-1, 128, 32, 32]          73,728
#          MaxPool2d-5          [-1, 128, 16, 16]               0
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,456
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#            Conv2d-10          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-11          [-1, 128, 16, 16]             256
#          ResBlock-12          [-1, 128, 16, 16]               0
#            Conv2d-13          [-1, 256, 16, 16]         294,912
#         MaxPool2d-14            [-1, 256, 8, 8]               0
#       BatchNorm2d-15            [-1, 256, 8, 8]             512
#              ReLU-16            [-1, 256, 8, 8]               0
#            Conv2d-17            [-1, 512, 8, 8]       1,179,648
#         MaxPool2d-18            [-1, 512, 4, 4]               0
#       BatchNorm2d-19            [-1, 512, 4, 4]           1,024
#              ReLU-20            [-1, 512, 4, 4]               0
#            Conv2d-21            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-22            [-1, 512, 4, 4]           1,024
#            Conv2d-23            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-24            [-1, 512, 4, 4]           1,024
#          ResBlock-25            [-1, 512, 4, 4]               0
#         MaxPool2d-26            [-1, 512, 1, 1]               0
#            Conv2d-27             [-1, 10, 1, 1]           5,120
# ================================================================
# Total params: 6,573,120
# Trainable params: 6,573,120
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.13
# Params size (MB): 25.07
# Estimated Total Size (MB): 31.22
# ----------------------------------------------------------------

# %% [markdown]
# # Define a Loss function and optimizer

# %%
from EVA4.Modules import LRFinder
import torch.optim as optim

model = net
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-6, weight_decay=0.01,momentum=0.9)
lr_finder = LRFinder(model, optimizer, criterion, device="cuda")
lr_finder.range_test(trainloader, end_lr=10, num_iter=100)
lr_finder.plot(show_lr=0.008) # to inspect the loss-learning rate graph
lr_finder.reset() # to reset the model and optimizer to their initial stat
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
#criterion = nn.NLLLoss()
optimizer = optim.SGD(net.parameters(), lr=0.10, momentum=0.9)
scheduler = optim.lr_scheduler.OneCycleLR(optimizer,
                                          max_lr=0.02, 
                                          steps_per_epoch=98, 
                                          pct_start=0.20, 
                                          epochs=25,
                                          anneal_strategy='linear',
                                          base_momentum=0.8)

# %% [markdown]
# # Training and Testing

# %%
# Load train and test model
from EVA4.Modules import *

train = train()
test = test()

for epoch in range(25):  # loop over the dataset multiple times

    train.execute(net, device, trainloader, optimizer, criterion, epoch,scheduler)
    test.execute(net, device, testloader, criterion)

print('Finished Training')
# Out:
#   0%|          | 0/98 [00:00<?, ?it/s]
# Epoch: 0
# Loss=1.3529 Batch_id=97 LR=0.0046 Accuracy=38.78: 100%|██████████| 98/98 [00:17<00:00,  5.60it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0028, Accuracy: 5004/10000 (50.04%)
#
#
# Epoch: 1
# Loss=1.1609 Batch_id=97 LR=0.0085 Accuracy=55.08: 100%|██████████| 98/98 [00:17<00:00,  5.66it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 5967/10000 (59.67%)
#
#
# Epoch: 2
# Loss=0.9653 Batch_id=97 LR=0.0123 Accuracy=64.33: 100%|██████████| 98/98 [00:17<00:00,  5.61it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0021, Accuracy: 6513/10000 (65.13%)
#
#
# Epoch: 3
# Loss=0.9014 Batch_id=97 LR=0.0162 Accuracy=66.05: 100%|██████████| 98/98 [00:17<00:00,  5.61it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0021, Accuracy: 6875/10000 (68.75%)
#
#
# Epoch: 4
# Loss=0.5993 Batch_id=97 LR=0.0200 Accuracy=72.16: 100%|██████████| 98/98 [00:17<00:00,  5.71it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0019, Accuracy: 7078/10000 (70.78%)
#
#
# Epoch: 5
# Loss=0.6190 Batch_id=97 LR=0.0190 Accuracy=75.58: 100%|██████████| 98/98 [00:17<00:00,  5.70it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0014, Accuracy: 7675/10000 (76.75%)
#
#
# Epoch: 6
# Loss=0.6071 Batch_id=97 LR=0.0180 Accuracy=79.23: 100%|██████████| 98/98 [00:17<00:00,  5.71it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0015, Accuracy: 7794/10000 (77.94%)
#
#
# Epoch: 7
# Loss=0.5778 Batch_id=97 LR=0.0170 Accuracy=80.65: 100%|██████████| 98/98 [00:17<00:00,  5.66it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0012, Accuracy: 8033/10000 (80.33%)
#
#
# Epoch: 8
# Loss=0.4323 Batch_id=97 LR=0.0160 Accuracy=83.10: 100%|██████████| 98/98 [00:17<00:00,  5.62it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0011, Accuracy: 8308/10000 (83.08%)
#
#
# Epoch: 9
# Loss=0.4029 Batch_id=97 LR=0.0150 Accuracy=84.07: 100%|██████████| 98/98 [00:17<00:00,  5.67it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0012, Accuracy: 8176/10000 (81.76%)
#
#
# Epoch: 10
# Loss=0.4447 Batch_id=97 LR=0.0140 Accuracy=85.55: 100%|██████████| 98/98 [00:17<00:00,  5.70it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0011, Accuracy: 8282/10000 (82.82%)
#
#
# Epoch: 11
# Loss=0.4123 Batch_id=97 LR=0.0130 Accuracy=86.13: 100%|██████████| 98/98 [00:17<00:00,  5.66it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0012, Accuracy: 8154/10000 (81.54%)
#
#
# Epoch: 12
# Loss=0.4199 Batch_id=97 LR=0.0120 Accuracy=86.84: 100%|██████████| 98/98 [00:17<00:00,  5.67it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0009, Accuracy: 8558/10000 (85.58%)
#
#
# Epoch: 13
# Loss=0.3248 Batch_id=97 LR=0.0110 Accuracy=88.30: 100%|██████████| 98/98 [00:17<00:00,  5.68it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0008, Accuracy: 8706/10000 (87.06%)
#
#
# Epoch: 14
# Loss=0.2813 Batch_id=97 LR=0.0100 Accuracy=89.07: 100%|██████████| 98/98 [00:17<00:00,  5.73it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0009, Accuracy: 8597/10000 (85.97%)
#
#
# Epoch: 15
# Loss=0.3219 Batch_id=97 LR=0.0090 Accuracy=89.91: 100%|██████████| 98/98 [00:17<00:00,  5.67it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0010, Accuracy: 8544/10000 (85.44%)
#
#
# Epoch: 16
# Loss=0.2864 Batch_id=97 LR=0.0080 Accuracy=90.67: 100%|██████████| 98/98 [00:17<00:00,  5.69it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0008, Accuracy: 8766/10000 (87.66%)
#
#
# Epoch: 17
# Loss=0.2804 Batch_id=97 LR=0.0070 Accuracy=91.09: 100%|██████████| 98/98 [00:17<00:00,  5.61it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0008, Accuracy: 8761/10000 (87.61%)
#
#
# Epoch: 18
# Loss=0.2377 Batch_id=97 LR=0.0060 Accuracy=91.94: 100%|██████████| 98/98 [00:19<00:00,  5.10it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0008, Accuracy: 8759/10000 (87.59%)
#
#
# Epoch: 19
# Loss=0.1865 Batch_id=97 LR=0.0050 Accuracy=92.62: 100%|██████████| 98/98 [00:18<00:00,  5.34it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0008, Accuracy: 8816/10000 (88.16%)
#
#
# Epoch: 20
# Loss=0.1938 Batch_id=97 LR=0.0040 Accuracy=93.35: 100%|██████████| 98/98 [00:18<00:00,  5.23it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0007, Accuracy: 8879/10000 (88.79%)
#
#
# Epoch: 21
# Loss=0.1650 Batch_id=97 LR=0.0030 Accuracy=93.80: 100%|██████████| 98/98 [00:18<00:00,  5.38it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0007, Accuracy: 8922/10000 (89.22%)
#
#
# Epoch: 22
# Loss=0.1785 Batch_id=97 LR=0.0020 Accuracy=94.41: 100%|██████████| 98/98 [00:18<00:00,  5.33it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0007, Accuracy: 8978/10000 (89.78%)
#
#
# Epoch: 23
# Loss=0.1083 Batch_id=97 LR=0.0010 Accuracy=95.07: 100%|██████████| 98/98 [00:19<00:00,  5.13it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 0.0006, Accuracy: 9008/10000 (90.08%)
#
#
# Epoch: 24
# Loss=0.1347 Batch_id=97 LR=-0.0000 Accuracy=95.75: 100%|██████████| 98/98 [00:19<00:00,  5.05it/s]
# Test set: Average loss: 0.0006, Accuracy: 9027/10000 (90.27%)
#
# Finished Training

# %% [markdown]
# # Misclassified images

# %%
plot_misclassified_images_w_gradcam(net,device,testloader,classes)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2416: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %% [markdown]
# # Plotting Train & Test Accuracy/Losses

# %% [markdown]
# # Evaluating test Accuracy over different classes

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images,labels = images.to(device),labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 100 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 66 %
# Accuracy of   cat : 70 %
# Accuracy of  deer : 85 %
# Accuracy of   dog : 100 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 92 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %

# %%
plot_train_test_acc_loss(train,test)
